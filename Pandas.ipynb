# %% [markdown]
# <a href="https://colab.research.google.com/github/zinakhazaee/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading data

# %%
# csv, excel, html, json, sql, xml,etc
data =  pd.read_csv('/content/drive/MyDrive/New dataset/Health_conditions_among_children_under_age_18__by_selected_characteristics__United_States.csv')

# %% [markdown]
# # Copying data

# %%
df = data.copy()

# %% [markdown]
# # Data overview

# %%
df.shape
# Out:
# (2744, 16)

# %%
df.size
# Out:
# 43904

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2744, step=1)

# %%
df.columns
# Out:
# Index(['INDICATOR', 'PANEL', 'PANEL_NUM', 'UNIT', 'UNIT_NUM', 'STUB_NAME',
#        'STUB_NAME_NUM', 'STUB_LABEL', 'STUB_LABEL_NUM', 'YEAR', 'YEAR_NUM',
#        'AGE', 'AGE_NUM', 'ESTIMATE', 'SE', 'FLAG'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744 entries, 0 to 2743
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDICATOR       2744 non-null   object
#  1   PANEL           2744 non-null   object
#  2   PANEL_NUM       2744 non-null   int64
#  3   UNIT            2744 non-null   object
#  4   UNIT_NUM        2744 non-null   int64
#  5   STUB_NAME       2744 non-null   object
#  6   STUB_NAME_NUM   2744 non-null   int64
#  7   STUB_LABEL      2744 non-null   object
#  8   STUB_LABEL_NUM  2744 non-null   float64
#  9   YEAR            2744 non-null   object
#  10  YEAR_NUM        2744 non-null   int64
#  11  AGE             2744 non-null   object
#  12  AGE_NUM         2744 non-null   float64
#  13  ESTIMATE        2516 non-null   float64
#  14  SE              2516 non-null   float64
#  15  FLAG            287 non-null    object
# dtypes: float64(4), int64(4), object(8)
# ...

# %%
df['PANEL'].value_counts()
# Out:
# Current asthma among persons under 18 years                                  350
# Asthma attack in last 12 months among persons under 18 years                 350
# Food allergy among persons under 18 years                                    350
# Skin allergy among persons under 18 years                                    350
# Hay fever or respiratory allergy among persons under 18 years                350
# Ear infections among persons under 18 years                                  350
# ADHD among persons under 18 years                                            322
# Serious emotional or behavioral difficulties among persons under 18 years    322
# Name: PANEL, dtype: int64

# %%
df.isna().sum()
# Out:
# INDICATOR            0
# PANEL                0
# PANEL_NUM            0
# UNIT                 0
# UNIT_NUM             0
# STUB_NAME            0
# STUB_NAME_NUM        0
# STUB_LABEL           0
# STUB_LABEL_NUM       0
# YEAR                 0
# YEAR_NUM             0
# AGE                  0
# AGE_NUM              0
# ESTIMATE           228
# SE                 228
# FLAG              2457
# dtype: int64

# %%
df.head(3)
# Out:
#                                        INDICATOR  \
# 0  Health conditions among children under age 18
# 1  Health conditions among children under age 18
# 2  Health conditions among children under age 18
#
#                                          PANEL  PANEL_NUM  \
# 0  Current asthma among persons under 18 years          1
# 1  Current asthma among persons under 18 years          1
# 2            ADHD among persons under 18 years          3
#
#                          UNIT  UNIT_NUM STUB_NAME  STUB_NAME_NUM  \
# 0  Percent of children, crude         1     Total              0
# 1  Percent of children, crude         1     Total              0
# 2  Percent of children, crude         1       Age              1
#
#        STUB_LABEL  STUB_LABEL_NUM       YEAR  YEAR_NUM             AGE  \
# 0  Under 18 years            0.00  1997-1999         1  Under 18 years
# 1  Under 18 years            0.00  2000-2002         2  Under 18 years
# ...

# %%
df.tail(3)
# Out:
#                                           INDICATOR  \
# 2741  Health conditions among children under age 18
# 2742  Health conditions among children under age 18
# 2743  Health conditions among children under age 18
#
#                                             PANEL  PANEL_NUM  \
# 2741  Ear infections among persons under 18 years          8
# 2742  Ear infections among persons under 18 years          8
# 2743  Ear infections among persons under 18 years          8
#
#                             UNIT  UNIT_NUM  \
# 2741  Percent of children, crude         1
# 2742  Percent of children, crude         1
# 2743  Percent of children, crude         1
#
#                                              STUB_NAME  STUB_NAME_NUM  \
# 2741  Health insurance status at the time of interview              6
# 2742  Health insurance status at the time of interview              6
# 2743  Health insurance status at the time of interview              6
#
# ...

# %%
df.dtypes
# Out:
# INDICATOR          object
# PANEL              object
# PANEL_NUM           int64
# UNIT               object
# UNIT_NUM            int64
# STUB_NAME          object
# STUB_NAME_NUM       int64
# STUB_LABEL         object
# STUB_LABEL_NUM    float64
# YEAR               object
# YEAR_NUM            int64
# AGE                object
# AGE_NUM           float64
# ESTIMATE          float64
# SE                float64
# FLAG               object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# INDICATOR     object
# PANEL         object
# UNIT          object
# STUB_NAME     object
# STUB_LABEL    object
# YEAR          object
# AGE           object
# FLAG          object
# dtype: object

# %%
df.dtypes[df.dtypes == 'float64']
# Out:
# STUB_LABEL_NUM    float64
# AGE_NUM           float64
# ESTIMATE          float64
# SE                float64
# dtype: object

# %%
df.dtypes[df.dtypes == 'int64']
# Out:
# PANEL_NUM        int64
# UNIT_NUM         int64
# STUB_NAME_NUM    int64
# YEAR_NUM         int64
# dtype: object

# %% [markdown]
# # Sorting data

# %%
df.sort_values(by='AGE' , ascending=True)
# Out:
#                                           INDICATOR  \
# 1371  Health conditions among children under age 18
# 374   Health conditions among children under age 18
# 373   Health conditions among children under age 18
# 372   Health conditions among children under age 18
# 371   Health conditions among children under age 18
# ...                                             ...
# 986   Health conditions among children under age 18
# 987   Health conditions among children under age 18
# 988   Health conditions among children under age 18
# 981   Health conditions among children under age 18
# 2743  Health conditions among children under age 18
#
#                                                   PANEL  PANEL_NUM  \
# 1371          Food allergy among persons under 18 years          5
# 374   Asthma attack in last 12 months among persons ...          2
# 373   Asthma attack in last 12 months among persons ...          2
# ...

# %% [markdown]
# # Statistical analysis of data

# %%
df.describe()
# Out:
#          PANEL_NUM  UNIT_NUM  STUB_NAME_NUM  STUB_LABEL_NUM     YEAR_NUM  \
# count  2744.000000    2744.0    2744.000000     2744.000000  2744.000000
# mean      4.520408       1.0       3.500000        3.718980     7.500000
# std       2.309363       0.0       1.733839        1.737358     4.031864
# min       1.000000       1.0       0.000000        0.000000     1.000000
# 25%       2.000000       1.0       2.000000        2.200000     4.000000
# 50%       5.000000       1.0       3.000000        3.600000     7.500000
# 75%       7.000000       1.0       5.000000        5.200000    11.000000
# max       8.000000       1.0       6.000000        6.200000    14.000000
#
#            AGE_NUM     ESTIMATE           SE
# count  2744.000000  2516.000000  2516.000000
# mean      0.268805     8.480008     0.441852
# std       0.679294     4.287880     0.364903
# min       0.000000     1.100000     0.100000
# 25%       0.000000     5.200000     0.200000
# ...

# %%
df[df.dtypes[df.dtypes == 'int64'].index].describe()
# Out:
#          PANEL_NUM  UNIT_NUM  STUB_NAME_NUM     YEAR_NUM
# count  2744.000000    2744.0    2744.000000  2744.000000
# mean      4.520408       1.0       3.500000     7.500000
# std       2.309363       0.0       1.733839     4.031864
# min       1.000000       1.0       0.000000     1.000000
# 25%       2.000000       1.0       2.000000     4.000000
# 50%       5.000000       1.0       3.000000     7.500000
# 75%       7.000000       1.0       5.000000    11.000000
# max       8.000000       1.0       6.000000    14.000000

# %% [markdown]
# # Data grouping

# %%
# sum, median, max, first, agg
df.groupby('STUB_NAME').size()
# Out:
# STUB_NAME
# Age                                                 420
# Health insurance status at the time of interview    448
# Hispanic origin and race                            448
# Percent of poverty level                            448
# Race                                                672
# Sex                                                 224
# Total                                                84
# dtype: int64

# %% [markdown]
# # Filtering by operators

# %%
# operators : (> < != == >= <=)  , ( & | ~ )
df[(df['STUB_NAME'] == 'Age') & (df['ESTIMATE'] > 10)]
# Out:
#                                           INDICATOR  \
# 34    Health conditions among children under age 18
# 35    Health conditions among children under age 18
# 36    Health conditions among children under age 18
# 37    Health conditions among children under age 18
# 38    Health conditions among children under age 18
# ...                                             ...
# 2412  Health conditions among children under age 18
# 2413  Health conditions among children under age 18
# 2414  Health conditions among children under age 18
# 2415  Health conditions among children under age 18
# 2416  Health conditions among children under age 18
#
#                                             PANEL  PANEL_NUM  \
# 34    Current asthma among persons under 18 years          1
# 35    Current asthma among persons under 18 years          1
# 36    Current asthma among persons under 18 years          1
# 37    Current asthma among persons under 18 years          1
# ...

# %% [markdown]
# # Deleting columns or rows

# %%
df.drop('FLAG' , axis= 1 , inplace=True)

# %%
df.drop(columns=['INDICATOR', 'PANEL'] )
# Out:
#       PANEL_NUM                        UNIT  UNIT_NUM  \
# 0             1  Percent of children, crude         1
# 1             1  Percent of children, crude         1
# 2             3  Percent of children, crude         1
# 3             3  Percent of children, crude         1
# 4             3  Percent of children, crude         1
# ...         ...                         ...       ...
# 2739          8  Percent of children, crude         1
# 2740          8  Percent of children, crude         1
# 2741          8  Percent of children, crude         1
# 2742          8  Percent of children, crude         1
# 2743          8  Percent of children, crude         1
#
#                                              STUB_NAME  STUB_NAME_NUM  \
# 0                                                Total              0
# 1                                                Total              0
# 2                                                  Age              1
# ...

# %%
df.drop([0] , axis=0 )
# Out:
#                                           INDICATOR  \
# 1     Health conditions among children under age 18
# 2     Health conditions among children under age 18
# 3     Health conditions among children under age 18
# 4     Health conditions among children under age 18
# 5     Health conditions among children under age 18
# ...                                             ...
# 2739  Health conditions among children under age 18
# 2740  Health conditions among children under age 18
# 2741  Health conditions among children under age 18
# 2742  Health conditions among children under age 18
# 2743  Health conditions among children under age 18
#
#                                             PANEL  PANEL_NUM  \
# 1     Current asthma among persons under 18 years          1
# 2               ADHD among persons under 18 years          3
# 3               ADHD among persons under 18 years          3
# 4               ADHD among persons under 18 years          3
# ...

# %%
df.drop(df[df['PANEL_NUM']==1].index )
# Out:
#                                           INDICATOR  \
# 2     Health conditions among children under age 18
# 3     Health conditions among children under age 18
# 4     Health conditions among children under age 18
# 353   Health conditions among children under age 18
# 354   Health conditions among children under age 18
# ...                                             ...
# 2739  Health conditions among children under age 18
# 2740  Health conditions among children under age 18
# 2741  Health conditions among children under age 18
# 2742  Health conditions among children under age 18
# 2743  Health conditions among children under age 18
#
#                                                   PANEL  PANEL_NUM  \
# 2                     ADHD among persons under 18 years          3
# 3                     ADHD among persons under 18 years          3
# 4                     ADHD among persons under 18 years          3
# ...

# %% [markdown]
# # Adding new columns

# %%
import numpy as np
df['New_Col'] = np.arange(0,df.shape[0])

# %%
df['New_col2'] = df[['STUB_NAME']]

# %%
df['New_col3'] = df['PANEL_NUM']+df['UNIT_NUM']

# %% [markdown]
# # Removing and replacing null

# %%
df.dropna(subset=['ESTIMATE'] , inplace= True)

# %%
pd.isna(df['ESTIMATE']).sum()
# Out:
# 0

# %%
df['SE'].fillna(0)
# Out:
# 2       0.2
# 3       0.3
# 4       0.3
# 5       0.2
# 6       0.2
#        ...
# 2739    0.5
# 2740    0.6
# 2741    0.5
# 2742    0.6
# 2743    0.6
# Name: SE, Length: 2516, dtype: float64

# %% [markdown]
# # Removing duplicated data

# %%
df.duplicated(subset=['PANEL']).sum()
# Out:
# 2508

# %%
df.drop_duplicates(subset= ['PANEL'])
# Out:
#                                           INDICATOR  \
# 2     Health conditions among children under age 18
# 5     Health conditions among children under age 18
# 353   Health conditions among children under age 18
# 1024  Health conditions among children under age 18
# 1169  Health conditions among children under age 18
# 1670  Health conditions among children under age 18
# 2044  Health conditions among children under age 18
# 2394  Health conditions among children under age 18
#
#                                                   PANEL  PANEL_NUM  \
# 2                     ADHD among persons under 18 years          3
# 5           Current asthma among persons under 18 years          1
# 353   Asthma attack in last 12 months among persons ...          2
# 1024  Serious emotional or behavioral difficulties a...          4
# 1169          Food allergy among persons under 18 years          5
# 1670          Skin allergy among persons under 18 years          6
# ...

# %% [markdown]
# # Unique values

# %%
df['STUB_LABEL'].unique()
# Out:
# array(['10-17 years', 'Under 18 years', '0-4 years', '5-17 years',
#        '5-9 years', 'Male', 'Female', 'White only',
#        'Black or African American only',
#        'American Indian or Alaska Native only', 'Asian only',
#        '2 or more races', 'Hispanic or Latino: All races',
#        'Not Hispanic or Latino: All races', '100%-199%',
#        'Not Hispanic or Latino: White only',
#        'Not Hispanic or Latino: Black or African American only',
#        'Below 100%', '200%-399%', '400% or more', 'Insured',
#        'Insured: Private', 'Insured: Medicaid', 'Uninsured',
#        'Native Hawaiian or Other Pacific Islander only'], dtype=object)

# %%
pd.Categorical(df['AGE'])
# Out:
# ['Under 18 years', 'Under 18 years', '10-17 years', '10-17 years', '10-17 years', ..., 'Under 18 years', 'Under 18 years', 'Under 18 years', 'Under 18 years', 'Under 18 years']
# Length: 2744
# Categories (5, object): ['0-4 years', '10-17 years', '5-17 years', '5-9 years', 'Under 18 years']

# %%
pd.Categorical(df['YEAR'])
# Out:
# ['1997-1999', '2000-2002', '1997-1999', '2000-2002', '2003-2005', ..., '2012-2014', '2013-2015', '2014-2016', '2015-2017', '2016-2018']
# Length: 2744
# Categories (14, object): ['1997-1999', '2000-2002', '2003-2005', '2006-2008', ..., '2013-2015',
#                           '2014-2016', '2015-2017', '2016-2018']

# %% [markdown]
# # Renaming columns

# %%
df.rename(columns={'New_Col': 'index'} , inplace=True)

# %% [markdown]
# # Indexing

# %%
df.set_index(['index'] , inplace=True)

# %%
df.reset_index()
# Out:
#       index                                      INDICATOR  \
# 0         2  Health conditions among children under age 18
# 1         3  Health conditions among children under age 18
# 2         4  Health conditions among children under age 18
# 3         5  Health conditions among children under age 18
# 4         6  Health conditions among children under age 18
# ...     ...                                            ...
# 2511   2739  Health conditions among children under age 18
# 2512   2740  Health conditions among children under age 18
# 2513   2741  Health conditions among children under age 18
# 2514   2742  Health conditions among children under age 18
# 2515   2743  Health conditions among children under age 18
#
#                                             PANEL  PANEL_NUM  \
# 0               ADHD among persons under 18 years          3
# 1               ADHD among persons under 18 years          3
# 2               ADHD among persons under 18 years          3
# ...

# %% [markdown]
# # Loc , iLoc

# %%
df.loc[3]
# Out:
# INDICATOR         Health conditions among children under age 18
# PANEL                         ADHD among persons under 18 years
# PANEL_NUM                                                     3
# UNIT                                 Percent of children, crude
# UNIT_NUM                                                      1
# STUB_NAME                                                   Age
# STUB_NAME_NUM                                                 1
# STUB_LABEL                                          10-17 years
# STUB_LABEL_NUM                                             1.22
# YEAR                                                  2000-2002
# YEAR_NUM                                                      2
# AGE                                                 10-17 years
# AGE_NUM                                                     2.2
# ESTIMATE                                                    9.0
# SE                                                          0.3
# ...

# %%
df.set_index(['STUB_NAME'] , inplace=True)

# %%
df.loc[['Age']]
# Out:
#                                                INDICATOR  \
# STUB_NAME
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# ...                                                  ...
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
#
#                                                  PANEL  PANEL_NUM  \
# STUB_NAME
# Age                  ADHD among persons under 18 years          3
# Age                  ADHD among persons under 18 years          3
# ...

# %%
df.loc[['Age']][['PANEL','PANEL_NUM']]
# Out:
#                                                  PANEL  PANEL_NUM
# STUB_NAME
# Age                  ADHD among persons under 18 years          3
# Age                  ADHD among persons under 18 years          3
# Age                  ADHD among persons under 18 years          3
# Age        Current asthma among persons under 18 years          1
# Age        Current asthma among persons under 18 years          1
# ...                                                ...        ...
# Age        Ear infections among persons under 18 years          8
# Age        Ear infections among persons under 18 years          8
# Age        Ear infections among persons under 18 years          8
# Age        Ear infections among persons under 18 years          8
# Age        Ear infections among persons under 18 years          8
#
# [406 rows x 2 columns]

# %%
df.iloc[10:30]
# Out:
#                                                INDICATOR  \
# STUB_NAME
# Total      Health conditions among children under age 18
# Total      Health conditions among children under age 18
# Total      Health conditions among children under age 18
# Total      Health conditions among children under age 18
# Total      Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# Age        Health conditions among children under age 18
# ...

# %%
df.iloc[-1]
# Out:
# INDICATOR            Health conditions among children under age 18
# PANEL                  Ear infections among persons under 18 years
# PANEL_NUM                                                        8
# UNIT                                    Percent of children, crude
# UNIT_NUM                                                         1
# STUB_NAME_NUM                                                    6
# STUB_LABEL                                               Uninsured
# STUB_LABEL_NUM                                                 6.2
# YEAR                                                     2016-2018
# YEAR_NUM                                                        14
# AGE                                                 Under 18 years
# AGE_NUM                                                        0.0
# ESTIMATE                                                       2.9
# SE                                                             0.6
# ...

# %%
df[['AGE'][:20]]
# Out:
#                                                              AGE
# STUB_NAME
# Age                                                  10-17 years
# Age                                                  10-17 years
# Age                                                  10-17 years
# Total                                             Under 18 years
# Total                                             Under 18 years
# ...                                                          ...
# Health insurance status at the time of interview  Under 18 years
# Health insurance status at the time of interview  Under 18 years
# Health insurance status at the time of interview  Under 18 years
# Health insurance status at the time of interview  Under 18 years
# Health insurance status at the time of interview  Under 18 years
#
# [2516 rows x 1 columns]

# %% [markdown]
# # Concatenate and merge

# %%
df1 = df[['INDICATOR', 'PANEL','UNIT_NUM']]
df2 = df[['STUB_NAME_NUM', 'STUB_LABEL','UNIT_NUM']]

# %%
df3 = pd.concat((df1,df2), axis=1 )

# %%
df4 = pd.merge(df1,df2,on='UNIT_NUM' , how= 'inner')

# %% [markdown]
# # Writing data

# %%
# excel, dict, latex, numpy, json, html, sql and etc.
df.to_('new_file.csv')

# %% [markdown]
# ## Access to code

# %% [markdown]
# ## https://github.com/zinakhazaee/Pandas
